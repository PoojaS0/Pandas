# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\pooja sonakar\OneDrive\Downloads\world_population.csv")
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df=pd.read_csv(r"C:\Users\pooja sonakar\OneDrive\Downloads\world_population.csv",index_col="Country")
df
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#                Country  Rank CCA3           Capital Continent  \
# 0          Afghanistan    36  AFG             Kabul      Asia
# 1              Albania   138  ALB            Tirana    Europe
# 2              Algeria    34  DZA           Algiers    Africa
# 3       American Samoa   213  ASM         Pago Pago   Oceania
# 4              Andorra   203  AND  Andorra la Vella    Europe
# ..                 ...   ...  ...               ...       ...
# 229  Wallis and Futuna   226  WLF          Mata-Utu   Oceania
# 230     Western Sahara   172  ESH          El Aaiún    Africa
# 231              Yemen    46  YEM             Sanaa      Asia
# 232             Zambia    63  ZMB            Lusaka    Africa
# 233           Zimbabwe    74  ZWE            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
df.loc['Albania']
# Out:
# Rank                                 138
# CCA3                                 ALB
# Capital                           Tirana
# Continent                         Europe
# 2022 Population                2842321.0
# 2020 Population                2866849.0
# 2015 Population                2882481.0
# 2010 Population                2913399.0
# 2000 Population                3182021.0
# 1990 Population                3295066.0
# 1980 Population                2941651.0
# 1970 Population                2324731.0
# Area (km²)                       28748.0
# Density (per km²)                98.8702
# Growth Rate                       0.9957
# World Population Percentage         0.04
# Name: Albania, dtype: object

# %%
df.iloc[1]
# Out:
# Rank                                 138
# CCA3                                 ALB
# Capital                           Tirana
# Continent                         Europe
# 2022 Population                2842321.0
# 2020 Population                2866849.0
# 2015 Population                2882481.0
# 2010 Population                2913399.0
# 2000 Population                3182021.0
# 1990 Population                3295066.0
# 1980 Population                2941651.0
# 1970 Population                2324731.0
# Area (km²)                       28748.0
# Density (per km²)                98.8702
# Growth Rate                       0.9957
# World Population Percentage         0.04
# Name: Albania, dtype: object

# %%
df.set_index(['Continent','Rank'],inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21536\2866720976.py in ?()
# ----> 1 df.set_index(['Continent','Rank'],inplace=True)
#       2 df
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['Continent', 'Rank'] are in the columns"

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     Continent  Rank CCA3           Capital  2022 Population  2020 Population  \
# 0        Asia    36  AFG             Kabul       41128771.0       38972230.0
# 1      Europe   138  ALB            Tirana        2842321.0        2866849.0
# 2      Africa    34  DZA           Algiers       44903225.0       43451666.0
# 3     Oceania   213  ASM         Pago Pago          44273.0          46189.0
# 4      Europe   203  AND  Andorra la Vella          79824.0          77700.0
# ..        ...   ...  ...               ...              ...              ...
# 229   Oceania   226  WLF          Mata-Utu          11572.0          11655.0
# 230    Africa   172  ESH          El Aaiún         575986.0         556048.0
# 231      Asia    46  YEM             Sanaa       33696614.0       32284046.0
# 232    Africa    63  ZMB            Lusaka       20017675.0       18927715.0
# 233    Africa    74  ZWE            Harare       16320537.0       15669666.0
#
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#     Continent  Rank CCA3           Capital  2022 Population  2020 Population  \
# 0        Asia    36  AFG             Kabul       41128771.0       38972230.0
# 1      Europe   138  ALB            Tirana        2842321.0        2866849.0
# 2      Africa    34  DZA           Algiers       44903225.0       43451666.0
# 3     Oceania   213  ASM         Pago Pago          44273.0          46189.0
# 4      Europe   203  AND  Andorra la Vella          79824.0          77700.0
# ..        ...   ...  ...               ...              ...              ...
# 229   Oceania   226  WLF          Mata-Utu          11572.0          11655.0
# 230    Africa   172  ESH          El Aaiún         575986.0         556048.0
# 231      Asia    46  YEM             Sanaa       33696614.0       32284046.0
# 232    Africa    63  ZMB            Lusaka       20017675.0       18927715.0
# 233    Africa    74  ZWE            Harare       16320537.0       15669666.0
#
# ...

# %%
df.set_index(['Continent','Rank'],inplace=True)
df
# Out:
#                CCA3           Capital  2022 Population  2020 Population  \
# Continent Rank
# Asia      36    AFG             Kabul       41128771.0       38972230.0
# Europe    138   ALB            Tirana        2842321.0        2866849.0
# Africa    34    DZA           Algiers       44903225.0       43451666.0
# Oceania   213   ASM         Pago Pago          44273.0          46189.0
# Europe    203   AND  Andorra la Vella          79824.0          77700.0
# ...             ...               ...              ...              ...
# Oceania   226   WLF          Mata-Utu          11572.0          11655.0
# Africa    172   ESH          El Aaiún         575986.0         556048.0
# Asia      46    YEM             Sanaa       33696614.0       32284046.0
# Africa    63    ZMB            Lusaka       20017675.0       18927715.0
#           74    ZWE            Harare       16320537.0       15669666.0
#
#                 2015 Population  2010 Population  2000 Population  \
# Continent Rank
# ...

# %%
df.sort_index(ascending=False)
# Out:
#                    CCA3      Capital  2022 Population  2020 Population  \
# Continent     Rank
# South America 231   FLK      Stanley           3780.0           3747.0
#               184   GUF      Cayenne         304557.0         290969.0
#               170   SUR   Paramaribo         618040.0         607065.0
#               164   GUY   Georgetown         808726.0         797202.0
#               133   URY   Montevideo        3422794.0        3429086.0
# ...                 ...          ...              ...              ...
# Africa        22    TZA       Dodoma       65497748.0       61704518.0
#               15    COD     Kinshasa       99010212.0       92853164.0
#               14    EGY        Cairo      110990103.0      107465134.0
#               12    ETH  Addis Ababa      123379924.0      117190911.0
#               6     NGA        Abuja      218541212.0      208327405.0
#
#                     2015 Population  2010 Population  2000 Population  \
# Continent     Rank
# ...

# %%
df.loc['Africa']
# Out:
#      CCA3       Capital  2022 Population  2020 Population  2015 Population  \
# Rank
# 34    DZA       Algiers       44903225.0       43451666.0       39543154.0
# 42    AGO        Luanda       35588987.0       33428485.0       28127721.0
# 77    BEN    Porto-Novo       13352864.0       12643123.0       10932783.0
# 144   BWA      Gaborone        2630296.0        2546402.0        2305171.0
# 58    BFA   Ouagadougou       22673762.0       21522626.0       18718019.0
# 78    BDI     Bujumbura       12889576.0       12220227.0       10727148.0
# 53    CMR       Yaounde       27914536.0       26491087.0       23012646.0
# 171   CPV         Praia         593149.0         582640.0         552166.0
# 117   CAF        Bangui        5579144.0        5343020.0        4819333.0
# 69    TCD     N'Djamena       17723315.0       16644701.0       14140274.0
# 163   COM        Moroni         836774.0         806166.0         730216.0
# ...

# %%
df.iloc[34]
# Out:
# CCA3                                  CMR
# Capital                           Yaounde
# 2022 Population                27914536.0
# 2020 Population                26491087.0
# 2015 Population                23012646.0
# 2010 Population                19878036.0
# 2000 Population                15091594.0
# 1990 Population                11430520.0
# 1980 Population                 8519891.0
# 1970 Population                 6452787.0
# Area (km²)                       475442.0
# Density (per km²)                 58.7128
# Growth Rate                        1.0263
# World Population Percentage          0.35
# Name: (Africa, 53), dtype: object
